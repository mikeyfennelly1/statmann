# %% [markdown]
# ## Import necessary files

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### importing the API

# %%
from nba_api.stats.endpoints import playercareerstats
import pandas as pd
import matplotlib.pyplot as plt

# Nikola Jokić
career = playercareerstats.PlayerCareerStats(player_id='203999') 

# pandas data frames (optional: pip install pandas)
careerDF = career.get_data_frames()[0]
year  = careerDF['SEASON_ID']
year_points = careerDF['PTS']

print(careerDF[['SEASON_ID', 'PTS']])

plt.figure(figsize=(10,6))
plt.plot(year, year_points, c="b")
plt.show()
# Out:
#   SEASON_ID   PTS
# 0   2015-16   796
# 1   2016-17  1221
# 2   2017-18  1385
# 3   2018-19  1604
# 4   2019-20  1456
# 5   2020-21  1898
# 6   2021-22  2004
# 7   2022-23  1690
# 8   2023-24   601
